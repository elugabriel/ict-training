# %% [markdown]
# <a href="https://colab.research.google.com/github/elugabriel/ict-training/blob/main/Module_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 1: Introduction to Data Science

# %% [markdown]
# ## 🎯 Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - ⚙️ Set up your Data Science environment using Anaconda or Google Colab.
# - 📒 Understand how to work with Jupyter Notebooks.
# - 🌐 Use Git and GitHub to manage your projects and version control.
# - 🔁 Describe the Data Science lifecycle and CRISP-DM methodology.
# - 📊 Explore your first real-world dataset (Iris) using basic Pandas.

# %% [markdown]
# ##  1. What is Data Science?
#
# Data Science is an interdisciplinary field that extracts meaningful insights from data using **mathematics**, **statistics**, **programming**, and **domain knowledge**.
#
# 🔍 It involves:
# - Data collection
# - Data cleaning & preprocessing
# - Exploratory data analysis (EDA)
# - Building and evaluating models
# - Communicating results

# %% [markdown]
# ##  2. The CRISP-DM Framework
#
# CRISP-DM stands for **Cross Industry Standard Process for Data Mining**. It is one of the most widely used data science workflows.
#
#
# ### CRISP-DM Stages:
# 1. **Business Understanding** – Define the problem.
# 2. **Data Understanding** – Gather and explore data.
# 3. **Data Preparation** – Clean and format data.
# 4. **Modeling** – Apply algorithms.
# 5. **Evaluation** – Measure and refine model performance.
# 6. **Deployment** – Deliver solution and monitor it.

# %% [markdown]
# ![800px-CRISP-DM_Process_Diagram2.png](data:image/png;base64,...)

# %% [markdown]
# ## 3. Setting Up Your Tools
# Option A: Local Setup
#
#     Install Anaconda 🐍
#
#     Use Anaconda Navigator or terminal to launch Jupyter Notebook.

# %% [markdown]
# ![anaconda.png](data:image/png;base64,...)
